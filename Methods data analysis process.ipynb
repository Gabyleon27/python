# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The examples will cover almost all the functions and methods you are likely to use in a typical data analysis process.

# %% [markdown]
# Read the Dataframe

# %%
df=pd.read_csv("/content/drive/MyDrive/ANA_1005_FACULTY/Week 12/Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# 1. Dropping Columns

# %%
df.drop(['RowNumber','CustomerId','Surname'],axis=1)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %% [markdown]
# 2.  Select particular columns while reading

# %%
df_specific=pd.read_csv('/content/drive/MyDrive/ANA_1005_FACULTY/Week 12/Churn_Modelling.csv',usecols=['Gender','Geography','Surname'])
df_specific.head()
# Out:
#     Surname Geography  Gender
# 0  Hargrave    France  Female
# 1      Hill     Spain  Female
# 2      Onio    France  Female
# 3      Boni    France  Female
# 4  Mitchell     Spain  Female

# %% [markdown]
# 3.  Reading a part of the dataframe

# %%
df_part=pd.read_csv("/content/drive/MyDrive/ANA_1005_FACULTY/Week 12/Churn_Modelling.csv",nrows=5000)
df_part.shape
# Out:
# (5000, 14)

# %%
df_part
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602    Hargrave          619    France  Female   42
# 1             2    15647311        Hill          608     Spain  Female   41
# 2             3    15619304        Onio          502    France  Female   42
# 3             4    15701354        Boni          699    France  Female   39
# 4             5    15737888    Mitchell          850     Spain  Female   43
# ...         ...         ...         ...          ...       ...     ...  ...
# 4995       4996    15583480      Morgan          807    France  Female   36
# 4996       4997    15620341     Nwebube          500   Germany    Male   44
# 4997       4998    15613886    Trevisan          722     Spain    Male   43
# 4998       4999    15792916  Ositadimma          559     Spain  Female   40
# 4999       5000    15710408  Cunningham          584     Spain  Female   38
#
# ...

# %% [markdown]
# 4. Sample

# %%
df.sample(n=1000)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 6951       6952    15738889      Shih          658    France    Male   42
# 3503       3504    15782630  Genovese          543    France    Male   35
# 1776       1777    15674851     T'ien          622    France    Male   38
# 1352       1353    15596552  Stephens          535   Germany    Male   48
# 763         764    15622750       Chu          742   Germany  Female   21
# ...         ...         ...       ...          ...       ...     ...  ...
# 7379       7380    15607746  Belstead          573    France  Female   36
# 1027       1028    15769948   Palerma          737   Germany    Male   35
# 4703       4704    15686812     Jones          692     Spain  Female   44
# 2127       2128    15703482    Walker          710   Germany    Male   34
# 9513       9514    15566378   Tillman          515    France    Male   48
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sample(frac=0.1)
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 6080       6081    15725945   Nweke          659     Spain  Female   42
# 8059       8060    15717643    Band          728    France  Female   34
# 7501       7502    15605341   Baird          681    France  Female   58
# 6640       6641    15815615    Kung          681    France    Male   36
# 9201       9202    15788183   Longo          458   Germany  Female   43
# ...         ...         ...     ...          ...       ...     ...  ...
# 5067       5068    15602282     Kao          587   Germany  Female   45
# 4974       4975    15744942  Steele          638     Spain  Female   55
# 8828       8829    15777708    Liao          824     Spain  Female   38
# 861         862    15809100   Nucci          548    France  Female   32
# 4896       4897    15640464  Parkes          605    France    Male   41
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# 5. Checking the missing values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# 6. Adding missing values using loc and iloc

# %% [markdown]
# loc: labels/columns iloc: index

# %%
missing_random=np.random.randint(10000,size=20)
missing_random
# Out:
# array([1573, 8378, 6040, 5107, 1406, 8634, 2876, 3144, 1593, 4936, 7490,
#         310, 5808, 3484, 1681, 9744, 9783, 7144, 5686, 7464])

# %%
df.loc[missing_random,['Geography','Balance']]=np.nan

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography          20
# Gender              0
# Age                 0
# Tenure              0
# Balance            20
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
df.iloc[missing_random,-1]=np.nan

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography          20
# Gender              0
# Age                 0
# Tenure              0
# Balance            20
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited             20
# dtype: int64

# %% [markdown]
# 7. Filling missing values

# %%
df['Geography'].value_counts()
# Out:
# France     5009
# Germany    2502
# Spain      2469
# Name: Geography, dtype: int64

# %%
mode=df['Geography'].value_counts().index[0]
mode
# Out:
# 'France'

# %%
df['Geography'].fillna(value=mode,inplace=True)

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance            20
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited             20
# dtype: int64

# %%
mean=df.Balance.mean()

# %%
df['Balance'].fillna(value=mean,inplace=True)

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance             0
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited             20
# dtype: int64

# %% [markdown]
# 8. Dropping missing values

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# 9. Selecting rows based on conditions

# %%
Germany=df[(df.Geography=='Germany')&(df.Exited==1)]

# %%
Germany
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148     Obinna          376   Germany  Female   29
# 16           17    15737452      Romeo          653   Germany    Male   58
# 46           47    15602280     Martin          829   Germany  Female   27
# 47           48    15771573    Okagbue          637   Germany  Female   39
# 53           54    15702298   Parkhill          655   Germany    Male   41
# ...         ...         ...        ...          ...       ...     ...  ...
# 9960       9961    15681026   Lucciano          795   Germany  Female   33
# 9975       9976    15666295      Smith          610   Germany    Male   50
# 9981       9982    15672754   Burbidge          498   Germany    Male   42
# 9982       9983    15768163    Griffin          655   Germany  Female   46
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# 10. Describing the conditions with query

# %%
Df1=df.query('80000 < Balance < 100000')
Df1
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 1             2    15647311            Hill          608     Spain  Female
# 31           32    15706552   Odinakachukwu          533    France    Male
# 54           55    15569590             Yoo          601   Germany    Male
# 69           70    15755648          Pisano          675    France  Female
# 80           81    15706021           Buley          665    France  Female
# ...         ...         ...             ...          ...       ...     ...
# 9965       9966    15690164            Shao          627   Germany  Female
# 9978       9979    15703563           P'eng          774    France    Male
# 9979       9980    15692664          Diribe          677    France  Female
# 9984       9985    15696175  Echezonachukwu          602   Germany    Male
# 9991       9992    15769959     Ajuluchukwu          597    France  Female
#
# ...

# %% [markdown]
# 11. Describing the conditions with isin

# %%
df[df['Tenure'].isin([4,6,9,10])]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148       Obinna          376   Germany  Female   29
# 8             9    15792365           He          501    France    Male   44
# 10           11    15767821       Bearce          528    France    Male   31
# 12           13    15632264          Kay          476    France  Female   34
# 17           18    15788218    Henderson          549     Spain  Female   24
# ...         ...         ...          ...          ...       ...     ...  ...
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9999      10000    15628319       Walker          792    France  Female   28
#
# ...

# %% [markdown]
# 12. The groupby function

# %%
df_mean=df[['Geography','Gender','Exited']].groupby(['Geography','Gender'],as_index=False).mean()

# %% [markdown]
# 13. Applying multiple aggregate functions with groupby

# %% [markdown]
# 14. Reset the index

# %%
df_new=df[['Geography','Gender','Exited']].groupby(['Geography','Gender'],as_index=False).mean()

# %% [markdown]
# 15. Set a particular column as the index

# %%
df.set_index('RowNumber')
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %% [markdown]
# 16. Inserting a new column

# %%
random=np.random.randint(10,size=6)
random
# Out:
# array([5, 9, 2, 8, 3, 3])

# %%
df_mean['Random']=random

# %%
df_new.insert(0,'Random',random)

# %%
df_new
# Out:
#    Random Geography  Gender    Exited
# 0       5    France  Female  0.203720
# 1       9    France    Male  0.126863
# 2       2   Germany  Female  0.374790
# 3       8   Germany    Male  0.276677
# 4       3     Spain  Female  0.211982
# 5       3     Spain    Male  0.131503

# %%
df_mean
# Out:
#   Geography  Gender    Exited  Random
# 0    France  Female  0.203720       5
# 1    France    Male  0.126863       9
# 2   Germany  Female  0.374790       2
# 3   Germany    Male  0.276677       8
# 4     Spain  Female  0.211982       3
# 5     Spain    Male  0.131503       3

# %% [markdown]
# 17. The where function

# %%
df4=df[['Geography','Gender','Exited','Balance']].groupby(['Geography','Gender'],as_index=False).mean()

# %%
df4
# Out:
#   Geography  Gender    Exited        Balance
# 0    France  Female  0.203720   60317.187188
# 1    France    Male  0.126863   63550.112206
# 2   Germany  Female  0.374790  119193.333563
# 3   Germany    Male  0.276677  120306.707919
# 4     Spain  Female  0.211982   59831.669945
# 5     Spain    Male  0.131503   63287.769400

# %%
df4.insert(0,'Random',random)
df4
# Out:
#    Random Geography  Gender    Exited        Balance
# 0       5    France  Female  0.203720   60317.187188
# 1       9    France    Male  0.126863   63550.112206
# 2       2   Germany  Female  0.374790  119193.333563
# 3       8   Germany    Male  0.276677  120306.707919
# 4       3     Spain  Female  0.211982   59831.669945
# 5       3     Spain    Male  0.131503   63287.769400

# %%
df4["Balance"]=df4["Balance"].where(df4['Random']==9,0)
df4
# Out:
#    Random Geography  Gender    Exited       Balance
# 0       5    France  Female  0.203720      0.000000
# 1       9    France    Male  0.126863  63550.112206
# 2       2   Germany  Female  0.374790      0.000000
# 3       8   Germany    Male  0.276677      0.000000
# 4       3     Spain  Female  0.211982      0.000000
# 5       3     Spain    Male  0.131503      0.000000

# %% [markdown]
# 18. The rank function

# %%
df['rank']=df['Balance'].rank(method='first',ascending=True).astype('int')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# 19. Number of unique values in a column

# %%
df.Geography.nunique()
# Out:
# 3

# %% [markdown]
# 20. The category data type

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited             float64
# rank                 int64
# dtype: object

# %%
df['Geography']=df['Geography'].astype('category')

# %%
df.dtypes
# Out:
# RowNumber             int64
# CustomerId            int64
# Surname              object
# CreditScore           int64
# Geography          category
# Gender               object
# Age                   int64
# Tenure                int64
# Balance             float64
# NumOfProducts         int64
# HasCrCard             int64
# IsActiveMember        int64
# EstimatedSalary     float64
# Exited              float64
# rank                  int64
# dtype: object

# %%
df.memory_usage()
# Out:
# Index              79840
# RowNumber          79840
# CustomerId         79840
# Surname            79840
# CreditScore        79840
# Geography          10112
# Gender             79840
# Age                79840
# Tenure             79840
# Balance            79840
# NumOfProducts      79840
# HasCrCard          79840
# IsActiveMember     79840
# EstimatedSalary    79840
# Exited             79840
# rank               79840
# dtype: int64

# %% [markdown]
# 21. Replacing values

# %% [markdown]
# 22.Reducing the decimal points of floats

# %% [markdown]
# 23.Calculating the percentage change through a column

# %% [markdown]
# 24.Filtering based on strings

# %% [markdown]
# 25.Styling a dataframe
