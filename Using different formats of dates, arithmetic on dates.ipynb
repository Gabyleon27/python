# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### We have to import the datetime module to work with dates

# %%
#Import datetime module
import datetime
x = datetime.datetime.now()
print(x)
# Out:
# 2022-07-27 17:55:05.213695

# %% [markdown]
# The date contains year, month, day, hour, minute, second, and microsecond.

# %% [markdown]
# ### Common formats are:
#
# 1. %Y: 4-digit year (2021)
# 2. %y: 2-digit year (21)
# 3. %m: 2-digit month (01)
# 4. %d: 2-digit day of the month (18)
# 5. %A: weekday (Monday)
# 6. %a: abbreviated weekday (Mon)
# 7. %B: month (January)
# 8. %b: abbreviated month (Jan)

# %%
#import datetime

x = datetime.datetime(2018, 6, 1)

print(x.strftime("%B"))
# Out:
# June

# %% [markdown]
# ### Question 1
# Extarct the day of today in short and full version format

# %%
x= datetime.datetime.now()
print(x.strftime('%D'))

x= datetime.datetime.now()
print(x.strftime('%d'))
# Out:
# 07/27/22
# 27

# %% [markdown]
# Once we have dates stored in dataset, we can extract the weekday, month, or quarter with the functions weekdays(), months(), quarters(). To extract the numeric values for days, months, and years, we can use the format() function, noting that the output is as text. For example,

# %%
# let us import the flights_subset dataset.
import pandas as pd
df = pd.read_csv("flights_subset.csv")
df.head()
# Out:
#      date  year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0  112013  2013      1    1     517.0        2.0     830.0       11.0      UA
# 1  112013  2013      1    1     533.0        4.0     850.0       20.0      UA
# 2  112013  2013      1    1     542.0        2.0     923.0       33.0      AA
# 3  112013  2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4  112013  2013      1    1     554.0       -4.0     740.0       12.0      UA
#
#   tailnum  flight origin dest  air_time  distance  hour  minute
# 0  N14228    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1  N24211    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2  N619AA    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3  N668DN     461    LGA  ATL     116.0       762   5.0    54.0
# 4  N39463    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
df.info()

# %%
# As we can see the date colmn is of type integer and we have to convert it to datetime format.
#We can also convert and change the format
df['date']= pd.to_datetime(df['date'], format='%d%m%Y')
df.info()

# we can also use astype function
#df['date'] = df['date'].astype('datetime64[ns]')
#df.info()


df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2198 entries, 0 to 2197
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       2198 non-null   datetime64[ns]
#  1   year       2198 non-null   int64
#  2   month      2198 non-null   int64
#  3   day        2198 non-null   int64
#  4   dep_time   2180 non-null   float64
#  5   dep_delay  2180 non-null   float64
#  6   arr_time   2179 non-null   float64
#  7   arr_delay  2177 non-null   float64
#  8   carrier    2198 non-null   object
#  9   tailnum    2194 non-null   object
#  10  flight     2198 non-null   int64
#  11  origin     2198 non-null   object
#  12  dest       2198 non-null   object
#  13  air_time   2177 non-null   float64
#  14  distance   2198 non-null   int64
#  15  hour       2180 non-null   float64
#  16  minute     2180 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(4)
# memory usage: 292.0+ KB
# ...

# %%
# Now we can work with this column and do some extraction. We can extract the year
df['date'].dt.year
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2013
# 4       2013
#         ...
# 2193    2013
# 2194    2013
# 2195    2013
# 2196    2013
# 2197    2013
# Name: date, Length: 2198, dtype: int64

# %%
# Extract the month
df['date'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2193    1
# 2194    1
# 2195    1
# 2196    1
# 2197    1
# Name: date, Length: 2198, dtype: int64

# %%
# Extract the day
df['date'].dt.day

# %%
# WE CAN ALSO ACCESS THE DAY NAME 

df['date'].dt.day_name()
# Out:
# 0       Tuesday
# 1       Tuesday
# 2       Tuesday
# 3       Tuesday
# 4       Tuesday
#          ...
# 2193     Sunday
# 2194     Sunday
# 2195     Sunday
# 2196     Sunday
# 2197     Sunday
# Name: date, Length: 2198, dtype: object

# %% [markdown]
# ### Challenge :
#
# Extarct the year, month and day and put them into separate columns in the same datefrom under the following names:
# Extracted_Year, Extracted_Month, Extarcetd_Day

# %%
dfnew=pd.DataFrame()
dfnew['Extracted_Year'] = df['date'].dt.year
dfnew['Extracted_Month'] = df['date'].dt.month
dfnew['Extracted_Day'] = df['date'].dt.day

print(dfnew)
# Out:
#       Extracted_Year  Extracted_Month  Extracted_Day
# 0               2013                1              1
# 1               2013                1              1
# 2               2013                1              1
# 3               2013                1              1
# 4               2013                1              1
# ...              ...              ...            ...
# 2193            2013                1              6
# 2194            2013                1              6
# 2195            2013                1              6
# 2196            2013                1              6
# 2197            2013                1              6
#
# [2198 rows x 3 columns]

# %% [markdown]
# ## Part 2: Perform arithmetic on dates

# %%
# In order to accomplish this goal, you’ll need to use read_excel.
X=df['date'].dt.year
Y=df['year']-X
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2193    0
# 2194    0
# 2195    0
# 2196    0
# 2197    0
# Length: 2198, dtype: int64

# %% [markdown]
# ### Challenge:
#
# Extarct the earliest and the most recent date in the date object

# %%
df['date'].min()
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
df['date'].max()
# Out:
# Timestamp('2013-01-06 00:00:00')

# %% [markdown]
# ### Challenge:
#
# Find the time difference between the earliest and most recent date

# %%
df['date'].max()-df['date'].min()
# Out:
# Timedelta('5 days 00:00:00')

# %% [markdown]
# ### Challenge:
#
# Filter the dataset to see only data ON Tuesday

# %%
# create the filter function by extracting the day 'Tuesday'
df['flights_days']=df['date'].dt.day_name()
filt=(df['flights_days'] =='Tuesday')
df.loc[filt]
# Out:
#           date  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0   2013-01-01  2013      1    1     517.0        2.0     830.0       11.0
# 1   2013-01-01  2013      1    1     533.0        4.0     850.0       20.0
# 2   2013-01-01  2013      1    1     542.0        2.0     923.0       33.0
# 3   2013-01-01  2013      1    1     554.0       -6.0     812.0      -25.0
# 4   2013-01-01  2013      1    1     554.0       -4.0     740.0       12.0
# ..         ...   ...    ...  ...       ...        ...       ...        ...
# 400 2013-01-01  2013      1    1    2128.0       -7.0      26.0      -24.0
# 401 2013-01-01  2013      1    1    2134.0       49.0      20.0       28.0
# 402 2013-01-01  2013      1    1    2205.0      285.0      46.0      246.0
# 403 2013-01-01  2013      1    1       NaN        NaN       NaN        NaN
# 404 2013-01-01  2013      1    1       NaN        NaN       NaN        NaN
#
# ...

# %% [markdown]
# ### Date slicing

# %% [markdown]
#  we can do filtering in a very easy way. that is , we can slice our data and do more filtering.
#  First set the date field as our index, then us ethe slicing methods

# %%
# Set the date as our index
df.set_index('date', inplace=True)
df.head()
# Out:
#             year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# date
# 2013-01-01  2013      1    1     517.0        2.0     830.0       11.0
# 2013-01-01  2013      1    1     533.0        4.0     850.0       20.0
# 2013-01-01  2013      1    1     542.0        2.0     923.0       33.0
# 2013-01-01  2013      1    1     554.0       -6.0     812.0      -25.0
# 2013-01-01  2013      1    1     554.0       -4.0     740.0       12.0
#
#            carrier tailnum  flight origin dest  air_time  distance  hour  \
# date
# 2013-01-01      UA  N14228    1545    EWR  IAH     227.0      1400   5.0
# 2013-01-01      UA  N24211    1714    LGA  IAH     227.0      1416   5.0
# 2013-01-01      AA  N619AA    1141    JFK  MIA     160.0      1089   5.0
# 2013-01-01      DL  N668DN     461    LGA  ATL     116.0       762   5.0
# 2013-01-01      UA  N39463    1696    EWR  ORD     150.0       719   5.0
#
#             minute flights_days
# date
# 2013-01-01    17.0      Tuesday
# ...

# %%
# Let us filter only the flights between first and second of January
df['2013-01-01':'2013-01-02']
# Out:
#             year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# date
# 2013-01-01  2013      1    1     517.0        2.0     830.0       11.0
# 2013-01-01  2013      1    1     533.0        4.0     850.0       20.0
# 2013-01-01  2013      1    1     542.0        2.0     923.0       33.0
# 2013-01-01  2013      1    1     554.0       -6.0     812.0      -25.0
# 2013-01-01  2013      1    1     554.0       -4.0     740.0       12.0
# ...          ...    ...  ...       ...        ...       ...        ...
# 2013-01-02  2013      1    2    2218.0       -7.0    2331.0       -9.0
# 2013-01-02  2013      1    2    2259.0      119.0     122.0      110.0
# 2013-01-02  2013      1    2       NaN        NaN       NaN        NaN
# 2013-01-02  2013      1    2       NaN        NaN       NaN        NaN
# 2013-01-02  2013      1    2       NaN        NaN       NaN        NaN
#
#            carrier tailnum  flight origin dest  air_time  distance  hour  \
# date
# ...

# %% [markdown]
# ### Challenge:
#
# Calculate the mean of the departure time between second and third of January

# %%
df['2013-01-01':'2013-01-02']['dep_time'].mean()
# Out:
# 1307.6471962616822

# %%
# !pip install nbconvert
# !jupyter nbconvert --to html /content/ANA_1005_LAB_2_2.ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [NbConvertApp] Converting notebook /content/ANA_1005_LAB_2_2.ipynb to html
# [NbConvertApp] Writing 334091 bytes to /content/ANA_1005_LAB_2_2.html
